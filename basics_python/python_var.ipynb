# %% [markdown]
# This ia my First program in ipynb

# %%
def sum_list(numbers):
    sum = 0
    for i in numbers:
        sum += i
    return sum
if __name__ == "__main__":    numbers = []
print(sum_list(numbers))
print(sum_list([1, 2, 3, 4, 5]))
# Out:
# 0

# %%
a = 10
b = 20
sum = a + b
print("The sum of", a, "and", b, "is", sum)
# Out:
# The sum of 10 and 20 is 30

# %%
print("Hello Ravindra Kumar Singh")
# Out:
# Hello Ravindra Kumar Singh
